# %% [markdown]
# # Python 基础实战练习
#
# ## 1. 变量与数据类型
# Python 中最基本的概念就是变量。你可以把变量想象成一个盒子，用来装数据。
#
# ### 任务 1：
# 定义一个变量 `name`，赋值为你的名字（字符串）。
# 定义一个变量 `age`，赋值为你的年龄（整数）。
# 然后打印一句话：`我的名字是 xxx，今年 xx 岁。`

# %%
# 在这里写下你的代码
# 提示：使用 print(f"...")

name = "你的名字"
age = 18

# print(...)

# %% [markdown]
# ## 2. 列表 (List)
# 列表可以存很多东西，用 `[]` 包裹。
#
# ### 任务 2：
# 创建一个列表 `fruits`，包含 "apple", "banana", "orange"。
# 然后打印列表的第二个元素（注意：Python 索引从 0 开始）。

# %%
# 在这里写下你的代码

# fruits = ...
# print(...)

# %% [markdown]
# # 流程控制
#
# **总题数**: 37 题
#
# ## 练习说明
# - 请认真阅读每道题目
# - 选择题、判断题、填空题请在下方填写答案
# - 编程题请在代码单元格中编写代码
# - 所有题目仅供练习，不计入成绩
#
# ---

# %% [markdown]
# ## 选择题
# 共 15 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 以下哪个不是 Python 的流程控制语句？
#
# **选项：**
# A. if
# B. for
# C. while
# D. switch
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# Python 中 elif 是什么的缩写？
#
# **选项：**
# A. else if
# B. else elif
# C. elif else
# D. if else
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（easy）
#
# for 循环通常用于什么情况？
#
# **选项：**
# A. 无限循环
# B. 遍历序列
# C. 条件循环
# D. 递归
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 4 题（medium）
#
# 以下哪个可以正确终止循环？
#
# **选项：**
# A. break
# B. stop
# C. end
# D. exit
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 5 题（medium）
#
# continue 语句的作用是什么？
#
# **选项：**
# A. 终止程序
# B. 跳过本次循环
# C. 暂停循环
# D. 继续下一次迭代
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 6 题（easy）
#
# range(1, 10, 2) 生成什么序列？
#
# **选项：**
# A. 1,2,3,4,5,6,7,8,9
# B. 1,3,5,7,9
# C. 1,3,5,7,9,11
# D. 2,4,6,8
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 7 题（medium）
#
# Python 中 pass 语句的作用是什么？
#
# **选项：**
# A. 跳过代码
# B. 空语句占位
# C. 抛出异常
# D. 终止程序
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 8 题（easy）
#
# if-elif-else 结构中，elif 可以出现多少次？
#
# **选项：**
# A. 0次
# B. 1次
# C. 任意次
# D. 最多2次
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 9 题（medium）
#
# else 子句可以与哪个循环配合使用？
#
# **选项：**
# A. 只限 for
# B. 只限 while
# C. for 和 while 都可以
# D. 都不可以
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 10 题（easy）
#
# enumerate() 函数返回什么？
#
# **选项：**
# A. 索引和值的元组
# B. 只返回值
# C. 只返回索引
# D. 列表
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 11 题（medium）
#
# zip() 函数的作用是什么？
#
# **选项：**
# A. 压缩文件
# B. 将多个序列打包
# C. 解压缩
# D. 排序
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 12 题（easy）
#
# 以下哪个运算符用于成员测试？
#
# **选项：**
# A. ==
# B. is
# C. in
# D. !=
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 13 题（medium）
#
# assert 语句的作用是什么？
#
# **选项：**
# A. 断言条件
# B. 打印信息
# C. 抛出异常
# D. 注释代码
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 14 题（medium）
#
# 三元表达式的语法是什么？
#
# **选项：**
# A. a if b else c
# B. b ? a : c
# C. if b a else c
# D. a ? b : c
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 15 题（easy）
#
# input() 函数返回什么类型？
#
# **选项：**
# A. int
# B. float
# C. str
# D. bool
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 判断题
# 共 10 题

# %% [markdown]
# ### 第 1 题（easy）
#
# Python 使用缩进来定义代码块。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# if 语句必须有 else 子句。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（easy）
#
# for 循环必须指定迭代次数。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 4 题（medium）
#
# break 语句只能退出当前层循环。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 5 题（easy）
#
# continue 语句会跳过本次循环剩余代码。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 6 题（medium）
#
# while 循环必须有终止条件。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 7 题（easy）
#
# range(5) 生成 0,1,2,3,4。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 8 题（medium）
#
# for 循环的 else 子句在 break 时不执行。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 9 题（easy）
#
# 列表推导式可以嵌套。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 10 题（medium）
#
# Python 没有 do-while 循环。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 编程题
# 共 6 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 编写程序：打印 1 到 10 的所有偶数
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 2 题（easy）
#
# 编写程序：计算 1 到 100 的累加和
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 3 题（medium）
#
# 编写程序：实现用户登录验证（最多3次尝试）
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 4 题（easy）
#
# 编写程序：使用列表推导式生成 1-10 的平方列表
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 5 题（medium）
#
# 编写程序：使用 enumerate 遍历列表并打印索引和值
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 6 题（easy）
#
# 编写程序：使用 zip 合并两个列表
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

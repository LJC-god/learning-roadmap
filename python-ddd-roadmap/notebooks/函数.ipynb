# %% [markdown]
# # 函数
#
# **总题数**: 12 题
#
# ## 练习说明
# - 请认真阅读每道题目
# - 选择题、判断题、填空题请在下方填写答案
# - 编程题请在代码单元格中编写代码
# - 所有题目仅供练习，不计入成绩
#
# ---

# %% [markdown]
# ## 选择题
# 共 6 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 如何定义函数？
#
# **选项：**
# A. function name():
# B. def name():
# C. create name():
# D. make name():
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# 函数参数默认值如何表示？
#
# **选项：**
# A. param= value
# B. param: value
# C. param == value
# D. param -> value
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（medium）
#
# 什么是 *args？
#
# **选项：**
# A. 关键字参数
# B. 可变位置参数
# C. 默认参数
# D. 命名参数
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 4 题（medium）
#
# 什么是 **kwargs？
#
# **选项：**
# A. 可变位置参数
# B. 可变关键字参数
# C. 默认参数
# D. 返回值
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 5 题（easy）
#
# return 语句的作用是什么？
#
# **选项：**
# A. 打印结果
# B. 返回函数值
# C. 结束函数
# D. 退出程序
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 6 题（medium）
#
# 以下哪个是有效的函数名？
#
# **选项：**
# A. my_function
# B. my-function
# C. my function
# D. 1function
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 判断题
# 共 2 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 函数必须要有 return 语句。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（medium）
#
# Python 函数可以返回多个值。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 编程题
# 共 2 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 编写程序：定义计算平方的函数
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 2 题（medium）
#
# 编写程序：定义带默认参数的函数
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

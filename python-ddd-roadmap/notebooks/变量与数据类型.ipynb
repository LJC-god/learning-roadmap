# %% [markdown]
# # 变量与数据类型
#
# **总题数**: 48 题
#
# ## 练习说明
# - 请认真阅读每道题目
# - 选择题、判断题、填空题请在下方填写答案
# - 编程题请在代码单元格中编写代码
# - 所有题目仅供练习，不计入成绩
#
# ---

# %% [markdown]
# ## 选择题
# 共 20 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 以下哪个不是 Python 的基本数据类型？
#
# **选项：**
# A. int
# B. float
# C. array
# D. str
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# 在 Python 中，变量必须先声明类型才能使用。
#
# **选项：**
# A. 正确
# B. 错误
# C. 有时需要
# D. 视情况而定
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（easy）
#
# 下列哪个是 Python 的整数类型？
#
# **选项：**
# A. int
# B. float
# C. str
# D. bool
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 4 题（easy）
#
# Python 中，布尔类型的值包括哪些？
#
# **选项：**
# A. 0 和 1
# B. True 和 False
# C. yes 和 no
# D. on 和 off
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 5 题（medium）
#
# type(3.14) 返回的结果是什么类型？
#
# **选项：**
# A. int
# B. float
# C. str
# D. decimal
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 6 题（easy）
#
# 如何将字符串转换为整数？
#
# **选项：**
# A. int('123')
# B. str(123)
# C. float('123')
# D. bool('123')
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 7 题（medium）
#
# 以下哪个函数可以获取变量的数据类型？
#
# **选项：**
# A. type()
# B. typeof()
# C. datatype()
# D. gettype()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 8 题（easy）
#
# 0b1010 表示什么？
#
# **选项：**
# A. 二进制数 10
# B. 八进制数 10
# C. 十六进制数 10
# D. 十进制数 10
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 9 题（medium）
#
# 0xFF 表示什么？
#
# **选项：**
# A. 二进制数 255
# B. 八进制数 255
# C. 十六进制数 255
# D. 十进制数 255
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 10 题（easy）
#
# 以下哪个是合法的变量名？
#
# **选项：**
# A. 2variable
# B. variable-2
# C. _variable
# D. class
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 11 题（medium）
#
# 以下哪个是 Python 的关键字？
#
# **选项：**
# A. myvar
# B. variable
# C. class
# D. my_class
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 12 题（easy）
#
# Python 中，单引号和双引号创建字符串有区别吗？
#
# **选项：**
# A. 有
# B. 没有
# C. 有时有
# D. 取决于内容
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 13 题（medium）
#
# str(123.45) 的结果是什么？
#
# **选项：**
# A. 123
# B. 123.45
# C. 123.0
# D. 错误
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 14 题（easy）
#
# len('hello') 返回什么？
#
# **选项：**
# A. 4
# B. 5
# C. 6
# D. hello
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 15 题（medium）
#
# hex(255) 返回什么？
#
# **选项：**
# A. 0xff
# B. 0xFF
# C. 0xff
# D. 0xFf
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 16 题（easy）
#
# 以下哪个不是不可变数据类型？
#
# **选项：**
# A. int
# B. str
# C. list
# D. tuple
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 17 题（medium）
#
# complex(1, 2) 创建的复数是什么？
#
# **选项：**
# A. 1+2i
# B. 1+2j
# C. 1.0+2.0j
# D. 3j
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 18 题（easy）
#
# type(None) 返回什么？
#
# **选项：**
# A. NoneType
# B. Null
# C. Void
# D. None
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 19 题（medium）
#
# round(3.14159, 2) 的结果是什么？
#
# **选项：**
# A. 3.14
# B. 3.142
# C. 3.1
# D. 3.0
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 20 题（easy）
#
# 在 Python 中，变量赋值使用什么运算符？
#
# **选项：**
# A. ==
# B. =
# C. <-
# D. :=
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 判断题
# 共 10 题

# %% [markdown]
# ### 第 1 题（easy）
#
# Python 变量在赋值时不需要声明类型。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# Python 中的字符串是不可变的。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（easy）
#
# Python 的整数类型有大小限制。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 4 题（medium）
#
# 在 Python 中，1 == '1' 返回 True。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 5 题（easy）
#
# True 在数值运算中等价于 1。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 6 题（easy）
#
# False 在数值运算中等价于 0。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 7 题（medium）
#
# is 和 == 运算符完全等价。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 8 题（easy）
#
# Python 支持链式赋值。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 9 题（medium）
#
# Python 支持多变量同时赋值。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 10 题（easy）
#
# del 可以删除变量。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 编程题
# 共 8 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 编写程序：创建变量 a、b、c，分别赋值 10、20、30
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 2 题（easy）
#
# 编写程序：交换两个变量的值
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 3 题（medium）
#
# 编写程序：判断一个变量的类型是否为字符串
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 4 题（easy）
#
# 编写程序：将字符串 '123' 转换为整数并相加
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 5 题（medium）
#
# 编写程序：打印一个浮点数的整数部分和小数部分
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 6 题（easy）
#
# 编写程序：创建一个复数并分别提取实部和虚部
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 7 题（medium）
#
# 编写程序：比较 '==' 和 'is' 的区别
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 8 题（easy）
#
# 编写程序：将十进制数转换为二进制、八进制、十六进制
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

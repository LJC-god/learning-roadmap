# %% [markdown]
# # 📚 Python 基础 - 变量与数据类型
#
# 本练习包含 50 道基础题目，检验你对 Python 变量和数据类型的理解。
#
# ---
#
# ## 📝 练习说明
# - **题型分布**：选择题 20 题、判断题 15 题、填空题 15 题
# - **难度**：入门级
# - **建议时间**：30 分钟
#
# ---
#
# ## 一、选择题 (1-20)

# %% [markdown]
# **1.** 以下哪个不是 Python 的关键字？
#
# A. `if`
#
# B. `elif`
#
# C. `do`
#
# D. `while`

# %% [markdown]
# **2.** Python 中整数类型的英文是？
#
# A. `integer`
#
# B. `int`
#
# C. `float`
#
# D. `long`

# %% [markdown]
# **3.** 下列哪个是合法的变量名？
#
# A. `2value`
#
# B. `_value`
#
# C. `value-1`
#
# D. `class`

# %% [markdown]
# **4.** `type(3.14)` 返回的类型是？
#
# A. `<class 'int'>`
#
# B. `<class 'float'>`
#
# C. `<class 'str'>`
#
# D. `<class 'decimal'>`

# %% [markdown]
# **5.** 字符串必须用以下哪种符号包裹？
#
# A. 只有单引号
#
# B. 只有双引号
#
# C. 单引号或双引号
#
# D. 必须用三引号

# %% [markdown]
# **6.** 下列哪个不是 Python 的基本数据类型？
#
# A. `list`
#
# B. `array`
#
# C. `dict`
#
# D. `tuple`

# %% [markdown]
# **7.** `bool` 类型只有几个取值？
#
# A. 1 个
#
# B. 2 个
#
# C. 3 个
#
# D. 无限个

# %% [markdown]
# **8.** Python 变量赋值使用什么符号？
#
# A. `==`
#
# B. `=`
#
# C. `:=`
#
# D. `->`

# %% [markdown]
# **9.** 以下哪个是合法的字符串？
#
# A. `'I'm learning'`
#
# B. `"I'm learning"`
#
# C. `'''I'm learning'''`
#
# D. `以上都合法`

# %% [markdown]
# **10.** Python 中注释使用什么符号？
#
# A. `//`
#
# B. `/* */`
#
# C. `#`
#
# D. `<!-- -->`

# %% [markdown]
# **11.** 下列哪个可以转换为整数？
#
# A. `int("123")`
#
# B. `int("abc")`
#
# C. `int("12.34")`
#
# D. `int(True)`

# %% [markdown]
# **12.** `10 // 3` 的结果是？
#
# A. `3.33`
#
# B. `3`
#
# C. `1`
#
# D. `3.0`

# %% [markdown]
# **13.** `2 ** 3` 表示什么运算？
#
# A. 2 × 3
#
# B. 2 + 3
#
# C. 2³ = 8
#
# D. 2 ÷ 3

# %% [markdown]
# **14.** 字符串 `len()` 函数的作用是？
#
# A. 计算字符串中字符的数量
#
# B. 转换为大写
#
# C. 去除空格
#
# D. 替换字符

# %% [markdown]
# **15.** 下列哪个是浮点数？
#
# A. `42`
#
# B. `-7`
#
# C. `3.14159`
#
# D. `True`

# %% [markdown]
# **16.** `str(123)` 的结果是？
#
# A. 123
#
# B. "123"
#
# C. [123]
#
# D. 抛出异常

# %% [markdown]
# **17.** Python 变量名区分大小写吗？
#
# A. 不区分
#
# B. 区分
#
# C. 只有系统变量区分
#
# D. 只有自定义变量区分

# %% [markdown]
# **18.** `"hello" + "world"` 的结果是？
#
# A. `"hello world"`
#
# B. `"helloworld"`
#
# C. 抛出异常
#
# D. `"hello" + "world"`

# %% [markdown]
# **19.** 下列哪个不是合法的整数表示？
#
# A. `100`
#
# B. `-50`
#
# C. `1_000`
#
# D. `1,000`

# %% [markdown]
# **20.** `type(None)` 返回的类型是？
#
# A. `<class 'NoneType'>`
#
# B. `<class 'None'>`
#
# C. `<class 'null'>`
#
# D. `<class 'void'>`

# %% [markdown]
# ---
#
# ## 二、判断题 (21-35)

# %% [markdown]
# **21.** Python 变量在使用前必须声明类型。

# %% [markdown]
# **22.** `"5" + 3` 可以直接运行。

# %% [markdown]
# **23.** 浮点数在计算机中可能存在精度误差。

# %% [markdown]
# **24.** 字符串是不可变类型。

# %% [markdown]
# **25.** `True` 在数值运算中等同于 1。

# %% [markdown]
# **26.** 变量名可以以数字开头。

# %% [markdown]
# **27.** `0b101` 是合法的二进制整数表示。

# %% [markdown]
# **28.** `"hello" * 3` 的结果是 `"hellohellohello"`。

# %% [markdown]
# **29.** Python 3 中整数没有大小限制。

# %% [markdown]
# **30.** `bool(0)` 返回 `False`。

# %% [markdown]
# **31.** `"hello"[0]` 返回 `"h"`。

# %% [markdown]
# **32.** 字符串可以使用 `+` 运算符进行拼接。

# %% [markdown]
# **33.** `None` 等同于空字符串 `""`。

# %% [markdown]
# **34.** `"5" == 5` 的结果是 `True`。

# %% [markdown]
# **35.** 变量可以同时赋不同类型的值。

# %% [markdown]
# ---
#
# ## 三、填空题 (36-50)

# %% [markdown]
# **36.** `print("I'm learning " + "Python")` 的输出是 _______________

# %% [markdown]
# **37.** `"hello".upper()` 返回 _______________

# %% [markdown]
# **38.** `"Python".lower()` 返回 _______________

# %% [markdown]
# **39.** `"hello".count('l')` 返回 _______________

# %% [markdown]
# **40.** `"hello"[1:4]` 返回 _______________

# %% [markdown]
# **41.** `"hello"[::-1]` 返回 _______________

# %% [markdown]
# **42.** `len("Python")` 返回 _______________

# %% [markdown]
# **43.** `"hello world".split()` 默认以 _______________ 分割

# %% [markdown]
# **44.** `"-".join(["a", "b", "c"])` 返回 _______________

# %% [markdown]
# **45.** `"  hello  ".strip()` 返回 _______________

# %% [markdown]
# **46.** `"hello".replace('l', 'L')` 返回 _______________

# %% [markdown]
# **47.** `"hello" in "hello world"` 返回 _______________

# %% [markdown]
# **48.** `"hello" * 2` 返回 _______________

# %% [markdown]
# **49.** `"{name} is {age}".format(name="Tom", age=20)` 返回 _______________

# %% [markdown]
# **50.** `type(1.0)` 返回 _______________

# %% [markdown]
# # 数据结构
#
# **总题数**: 18 题
#
# ## 练习说明
# - 请认真阅读每道题目
# - 选择题、判断题、填空题请在下方填写答案
# - 编程题请在代码单元格中编写代码
# - 所有题目仅供练习，不计入成绩
#
# ---

# %% [markdown]
# ## 选择题
# 共 10 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 以下哪个不是 Python 的基本数据结构？
#
# **选项：**
# A. list
# B. tuple
# C. array
# D. dictionary
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# 列表使用什么括号？
#
# **选项：**
# A. ()
# B. []
# C. {}
# D. <>
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（easy）
#
# 元组使用什么括号？
#
# **选项：**
# A. ()
# B. []
# C. {}
# D. <>
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 4 题（easy）
#
# 字典使用什么括号？
#
# **选项：**
# A. ()
# B. []
# C. {}
# D. <>
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 5 题（medium）
#
# 以下哪个数据结构是不可变的？
#
# **选项：**
# A. list
# B. dict
# C. set
# D. tuple
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 6 题（easy）
#
# 如何获取列表的第一个元素？
#
# **选项：**
# A. list[0]
# B. list[1]
# C. list.first()
# D. list[1:]
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 7 题（easy）
#
# 列表的哪个方法可以添加元素？
#
# **选项：**
# A. add()
# B. append()
# C. insert()
# D. 两者都可以
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 8 题（medium）
#
# 如何删除列表中的元素？
#
# **选项：**
# A. remove()
# B. del
# C. pop()
# D. 都可以
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 9 题（medium）
#
# set 有什么特点？
#
# **选项：**
# A. 有序
# B. 无序不重复
# C. 可修改
# D. 可包含所有类型
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 10 题（medium）
#
# 字典的键有什么限制？
#
# **选项：**
# A. 必须是字符串
# B. 必须唯一
# C. 必须是数字
# D. 必须有序
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 判断题
# 共 3 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 列表是有序的数据结构。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# 元组是不可变的。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（medium）
#
# 集合不支持索引操作。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 编程题
# 共 3 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 编写程序：创建列表并添加元素
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 2 题（medium）
#
# 编写程序：使用列表推导式创建新列表
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 3 题（medium）
#
# 编写程序：使用字典存储和访问数据
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

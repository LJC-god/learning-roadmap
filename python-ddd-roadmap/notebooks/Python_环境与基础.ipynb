# %% [markdown]
# # Python 环境与基础
#
# **总题数**: 50 题
#
# ## 练习说明
# - 请认真阅读每道题目
# - 选择题、判断题、填空题请在下方填写答案
# - 编程题请在代码单元格中编写代码
# - 所有题目仅供练习，不计入成绩
#
# ---

# %% [markdown]
# ## 选择题
# 共 21 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 以下哪个不是 Python 语言的特性？
#
# **选项：**
# A. 解释型语言
# B. 面向对象
# C. 需要编译
# D. 跨平台
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# Python 源代码文件的默认扩展名是什么？
#
# **选项：**
# A. .java
# B. .py
# C. .cpp
# D. .c
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（easy）
#
# 如何启动 Python 交互式解释器？
#
# **选项：**
# A. python
# B. py
# C. python3
# D. 都可以
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 4 题（easy）
#
# 在 Python 中，单行注释使用什么符号？
#
# **选项：**
# A. //
# B. #
# C. /*
# D. --
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 5 题（medium）
#
# PEP 是什么的缩写？
#
# **选项：**
# A. Python Enhancement Proposal
# B. Python Edition Protocol
# C. Program Enhancement Process
# D. Python Execution Path
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 6 题（medium）
#
# 以下哪个不是 Python 的实现版本？
#
# **选项：**
# A. CPython
# B. Jython
# C. Pyython
# D. IronPython
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 7 题（easy）
#
# Python 2.x 和 Python 3.x 的主要区别是什么？
#
# **选项：**
# A. 语法完全相同
# B. print 语句变为函数
# C. 没有区别
# D. 性能差异很大
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 8 题（easy）
#
# 如何在命令行中运行 Python 脚本？
#
# **选项：**
# A. python script.py
# B. run script.py
# C. execute script.py
# D. start script.py
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 9 题（medium）
#
# IDLE 是什么？
#
# **选项：**
# A. Python 的集成开发环境
# B. 一种数据库
# C. 一种操作系统
# D. 一种编程语言
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 10 题（easy）
#
# Python 是一种什么类型的语言？
#
# **选项：**
# A. 编译型语言
# B. 解释型语言
# C. 汇编语言
# D. 机器语言
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 11 题（medium）
#
# 以下哪个不是常用的 Python IDE？
#
# **选项：**
# A. PyCharm
# B. VS Code
# C. Eclipse
# D. MySQL
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 12 题（easy）
#
# 如何查看 Python 版本？
#
# **选项：**
# A. python --version
# B. python -v
# C. 两者都可以
# D. 都不可以
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 13 题（medium）
#
# pip 是什么？
#
# **选项：**
# A. Python 包管理工具
# B. Python 解释器
# C. Python 调试器
# D. Python 编译器
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 14 题（medium）
#
# 如何安装 Python 包？
#
# **选项：**
# A. pip install 包名
# B. python install 包名
# C. install 包名
# D. get 包名
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 15 题（easy）
#
# venv 或 virtualenv 是什么？
#
# **选项：**
# A. 代码编辑器
# B. 版本控制系统
# C. 虚拟环境管理工具
# D. 调试工具
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 16 题（medium）
#
# 使用虚拟环境的主要目的是什么？
#
# **选项：**
# A. 提高运行速度
# B. 隔离项目依赖
# C. 增加代码安全性
# D. 减少内存占用
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 17 题（easy）
#
# Python 的创始人是？
#
# **选项：**
# A. Guido van Rossum
# B. James Gosling
# C. Bjarne Stroustrup
# D. Dennis Ritchie
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 18 题（medium）
#
# Python 首次发布是在哪一年？
#
# **选项：**
# A. 1989
# B. 1991
# C. 1995
# D. 2000
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 19 题（easy）
#
# 以下哪种不是 Python 的编程范式？
#
# **选项：**
# A. 面向过程
# B. 面向对象
# C. 函数式
# D. 硬件级编程
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 20 题（medium）
#
# 在 Jupyter Notebook 中，运行单元格使用什么快捷键？
#
# **选项：**
# A. Ctrl+C
# B. Shift+Enter
# C. Alt+Enter
# D. Ctrl+Enter
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 21 题（medium）
#
# Anaconda 是什么？
#
# **选项：**
# A. Python 解释器
# B. Python 包发行版
# C. 代码编辑器
# D. 操作系统
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 判断题
# 共 11 题

# %% [markdown]
# ### 第 1 题（easy）
#
# Python 是一种编译型语言。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# Python 代码在执行前需要先编译。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（easy）
#
# Python 支持多种编程范式。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 4 题（easy）
#
# Python 是开源免费的。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 5 题（medium）
#
# Python 2.x 仍然是官方推荐使用的版本。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 6 题（easy）
#
# Python 代码块通过缩进来定义。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 7 题（medium）
#
# 所有 Python 实现都使用 GIL。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 8 题（easy）
#
# Python 可以在 Windows、Linux、Mac 等操作系统上运行。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 9 题（medium）
#
# Python 3.x 完全向后兼容 Python 2.x。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 10 题（easy）
#
# 在 Python 中，变量不需要声明类型。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 11 题（medium）
#
# Jython 代码可以调用 Java 类库。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 编程题
# 共 8 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 编写程序：打印 Hello, World!
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 2 题（easy）
#
# 编写程序：计算并打印 1+2+3+...+100 的和
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 3 题（medium）
#
# 编写程序：打印当前 Python 版本信息
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 4 题（easy）
#
# 编写程序：打印你的名字和当前日期
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 5 题（medium）
#
# 编写程序：查看已安装的所有包及其版本
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 6 题（easy）
#
# 编写程序：在 Python 交互模式下计算 2 的 10 次方
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 7 题（medium）
#
# 编写程序：创建一个简单的 Python 脚本并运行它
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 8 题（easy）
#
# 编写程序：使用帮助功能查看 print 函数的使用方法
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

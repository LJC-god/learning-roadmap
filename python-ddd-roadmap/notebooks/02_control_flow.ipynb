# %% [markdown]
# # 📚 Python 基础 - 流程控制 (if/else/for/while)
#
# 本练习包含 50 道流程控制相关的练习题。
#
# ---
#
# ## 一、选择题 (1-20)

# %% [markdown]
# **1.** 以下哪个不是 Python 的比较运算符？
#
# A. `==`
#
# B. `!=`
#
# C. `=<`
#
# D. `<=`

# %% [markdown]
# **2.** `if` 语句后面必须跟什么？
#
# A. 大括号 `{ }`
#
# B. 冒号 `:`
#
# C. 分号 `;`
#
# D. 括号 `( )`

# %% [markdown]
# **3.** 以下哪个表达式返回 `True`？
#
# A. `5 > 10 and 3 < 4`
#
# B. `5 > 10 or 3 < 4`
#
# C. `not 5 > 10`
#
# D. `B 和 C 都对`

# %% [markdown]
# **4.** `range(5)` 生成的范围是？
#
# A. `[0, 1, 2, 3, 4]`
#
# B. `[1, 2, 3, 4, 5]`
#
# C. `[0, 1, 2, 3, 4, 5]`
#
# D. `[0, 1, 2, 3]`

# %% [markdown]
# **5.** `break` 语句的作用是？
#
# A. 跳过当前循环
#
# B. 终止整个循环
#
# C. 退出函数
#
# D. 抛出异常

# %% [markdown]
# **6.** `continue` 语句的作用是？
#
# A. 终止整个循环
#
# B. 跳过本次循环，继续下一次
#
# C. 退出函数
#
# D. 重新开始循环

# %% [markdown]
# **7.** `for` 循环可以遍历哪些类型？
#
# A. 只有列表
#
# B. 只有字符串
#
# C. 所有可迭代对象
#
# D. 只有数字

# %% [markdown]
# **8.** `while True:` 会产生什么？
#
# A. 编译错误
#
# B. 无限循环
#
# C. 什么都不执行
#
# D. 执行一次

# %% [markdown]
# **9.** `elif` 的含义是？
#
# A. 如果...否则如果...
#
# B. 结束判断
#
# C. 否则...
#
# D. 嵌套判断

# %% [markdown]
# **10.** `pass` 语句的作用是？
#
# A. 跳过代码
#
# B. 占位，什么都不做
#
# C. 退出程序
#
# D. 打印内容

# %% [markdown]
# **11.** `else` 可以和哪个语句搭配？
#
# A. 只有 `if`
#
# B. `if`, `for`, `while`
#
# C. 只有 `for`
#
# D. 只有 `while`

# %% [markdown]
# **12.** `range(1, 10, 2)` 生成的序列是？
#
# A. `[1, 3, 5, 7, 9]`
#
# B. `[1, 3, 5, 7]`
#
# C. `[1, 2, 3, 4, 5]`
#
# D. `[0, 2, 4, 6, 8]`

# %% [markdown]
# **13.** 三元运算符 `x if condition else y` 表示？
#
# A. 如果 condition 成立则返回 x，否则返回 y
#
# B. 如果 condition 成立则返回 y，否则返回 x
#
# C. 条件为真时执行 x
#
# D. 循环执行 x

# %% [markdown]
# **14.** `and` 运算符的真值表是？
#
# A. 有一个 True 就返回 True
#
# B. 两个都为 True 才返回 True
#
# C. 返回最后一个值
#
# D. 总是返回 False

# %% [markdown]
# **15.** `or` 运算符的真值表是？
#
# A. 有一个 True 就返回 True
#
# B. 两个都为 True 才返回 True
#
# C. 返回最后一个值
#
# D. 总是返回 False

# %% [markdown]
# **16.** `not True` 的结果是？
#
# A. `True`
#
# B. `False`
#
# C. `None`
#
# D. `Error`

# %% [markdown]
# **17.** 以下哪个是合法的循环变量？
#
# A. `for i in range(5):`
#
# B. `for 5 in range(5):`
#
# C. `while i < 5:` (i 未定义)
#
# D. `if x = 5:`

# %% [markdown]
# **18.** `for-else` 结构中，else 什么时候执行？
#
# A. 每次循环都执行
#
# B. 循环正常结束后执行
#
# C. 遇到 break 时执行
#
# D. 永不执行

# %% [markdown]
# **19.** 判断一个数是否为偶数，正确的条件是？
#
# A. `n % 2 == 0`
#
# B. `n % 2 = 0`
#
# C. `n / 2 == 0`
#
# D. `n * 2 == 0`

# %% [markdown]
# **20.** `while` 循环和 `for` 循环的主要区别是？
#
# A. `for` 不能遍历
#
# B. `while` 需要计数器
#
# C. `for` 通常用于已知次数，`while` 用于条件
#
# D. 没有区别

# %% [markdown]
# ---
#
# ## 二、判断题 (21-35)

# %% [markdown]
# **21.** Python 使用缩进来定义代码块。

# %% [markdown]
# **22.** `if` 语句可以没有 `else` 分支。

# %% [markdown]
# **23.** `for` 循环必须指定循环次数。

# %% [markdown]
# **24.** `break` 只能退出当前循环。

# %% [markdown]
# **25.** `continue` 会跳过本次循环剩余代码。

# %% [markdown]
# **26.** `pass` 可以用作 `if` 语句的占位符。

# %% [markdown]
# **27.** `range(0)` 会生成空序列。

# %% [markdown]
# **28.** 多个 `if` 语句可以独立存在。

# %% [markdown]
# **29.** `elif` 可以单独使用，不需要 `if`。

# %% [markdown]
# **30.** `while` 循环必须有终止条件。

# %% [markdown]
# **31.** `for i in [1,2,3]:` 会循环 3 次。

# %% [markdown]
# **32.** 逻辑运算符 `and` 优先级高于 `or`。

# %% [markdown]
# **33.** `not (a or b)` 等价于 `(not a) and (not b)`。

# %% [markdown]
# **34.** 可以使用 `for-else` 来检测循环是否被 break。

# %% [markdown]
# **35.** 嵌套循环的内层循环每次都会完整执行。

# %% [markdown]
# ---
#
# ## 三、填空题 (36-50)

# %% [markdown]
# **36.** `for i in range(10): print(i)` 输出的第一个数字是 _______________

# %% [markdown]
# **37.** `for i in range(1, 10):` 循环会执行 _______________ 次

# %% [markdown]
# **38.** 打印 1-100 所有偶数的代码是：
# ```python
# for i in range(________):
#     if i % 2 == 0:
#         print(i)
# ```

# %% [markdown]
# **39.** `break` 语句用于 _______________ 循环

# %% [markdown]
# **40.** `continue` 语句用于 _______________ 本次循环

# %% [markdown]
# **41.** 使用 _______________ 可以实现死循环

# %% [markdown]
# **42.** `if-elif-else` 中，最多可以有 _______________ 个 `elif`

# %% [markdown]
# **43.** `pass` 的作用是 _______________

# %% [markdown]
# **44.** `"Python".find("on")` 返回 _______________

# %% [markdown]
# **45.** `all([True, True, False])` 返回 _______________

# %% [markdown]
# **46.** `any([False, False, True])` 返回 _______________

# %% [markdown]
# **47.** 三元表达式 `1 if True else 2` 返回 _______________

# %% [markdown]
# **48.** `list(range(5, 0, -1))` 返回 _______________

# %% [markdown]
# **49.** 嵌套两层循环，外层 3 次，内层 5 次，总共执行 _______________ 次

# %% [markdown]
# **50.** `bool([])` 和 `bool([1])` 分别返回 _______________ 和 _______________

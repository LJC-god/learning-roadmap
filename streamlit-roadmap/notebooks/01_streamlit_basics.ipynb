# %% [markdown]
# # 📚 Streamlit 入门 - 基础组件
#
# 本练习包含 50 道 Streamlit 基础组件相关的练习题。
#
# ---
#
# ## 一、选择题 (1-20)

# %% [markdown]
# **1.** 安装 Streamlit 的命令是？
#
# A. `pip install streamlit`
#
# B. `pip install streamlit-ai`
#
# C. `conda install streamlit`
#
# D. A 和 C 都对

# %% [markdown]
# **2.** 启动 Streamlit 应用的命令是？
#
# A. `streamlit run app.py`
#
# B. `python app.py`
#
# C. `streamlit start app.py`
#
# D. `python -m streamlit app.py`

# %% [markdown]
# **3.** 显示标题的函数是？
#
# A. `st.heading()`
#
# B. `st.title()`
#
# C. `st.header()`
#
# D. `st.h1()`

# %% [markdown]
# **4.** `st.write()` 可以显示什么？
#
# A. 只能显示文本
#
# B. 只能显示数据
#
# C. 多种类型的内容
#
# D. 只能显示图像

# %% [markdown]
# **5.** 创建按钮的函数是？
#
# A. `st.button()`
#
# B. `st.click()`
#
# C. `st.input()`
#
# D. `st.action()`

# %% [markdown]
# **6.** `st.text_input()` 返回什么类型？
#
# A. `str`
#
# B. `int`
#
# C. `float`
#
# D. `bool`

# %% [markdown]
# **7.** 创建数字输入框的函数是？
#
# A. `st.number_input()`
#
# B. `st.int_input()`
#
# C. `st.numeric_input()`
#
# D. `st.float_input()`

# %% [markdown]
# **8.** `st.slider()` 返回什么类型？
#
# A. `int`
#
# B. `float`
#
# C. `int` 或 `float`
#
# D. `str`

# %% [markdown]
# **9.** 创建下拉选择框的函数是？
#
# A. `st.select()`
#
# B. `st.dropdown()`
#
# C. `st.selectbox()`
#
# D. `st.choose()`

# %% [markdown]
# **10.** 创建复选框的函数是？
#
# A. `st.check()`
#
# B. `st.toggle()`
#
# C. `st.checkbox()`
#
# D. `st.switch()`

# %% [markdown]
# **11.** `st.multiselect()` 返回什么类型？
#
# A. `str`
#
# B. `list`
#
# C. `tuple`
#
# D. `set`

# %% [markdown]
# **12.** 显示数据的函数是？
#
# A. `st.show()`
#
# B. `st.data()`
#
# C. `st.dataframe()`
#
# D. `st.table()`

# %% [markdown]
# **13.** 显示进度条的函数是？
#
# A. `st.progress()`
#
# B. `st.loading()`
#
# C. `st.bar()`
#
# D. `st.status()`

# %% [markdown]
# **14.** `st.success()` 显示什么颜色的消息？
#
# A. 绿色
#
# B. 红色
#
# C. 黄色
#
# D. 蓝色

# %% [markdown]
# **15.** 创建时间选择的函数是？
#
# A. `st.time_select()`
#
# B. `st.date_input()`
#
# C. `st.time_input()`
#
# D. `st.date_picker()`

# %% [markdown]
# **16.** 显示图片的函数是？
#
# A. `st.image()`
#
# B. `st.picture()`
#
# C. `st.img()`
#
# D. `st.photo()`

# %% [markdown]
# **17.** 显示音频的函数是？
#
# A. `st.sound()`
#
# B. `st.audio()`
#
# C. `st.music()`
#
# D. `st.voice()`

# %% [markdown]
# **18.** 创建分隔线的函数是？
#
# A. `st.divider()`
#
# B. `st.line()`
#
# C. `st.separator()`
#
# D. `st.hr()`

# %% [markdown]
# **19.** `st.expander()` 的作用是？
#
# A. 展开/折叠内容
#
# B. 删除内容
#
# C. 隐藏内容
#
# D. 移动内容

# %% [markdown]
# **20.** `st.columns(3)` 创建几个列？
#
# A. 1 列
#
# B. 2 列
#
# C. 3 列
#
# D. 4 列

# %% [markdown]
# ---
#
# ## 二、判断题 (21-35)

# %% [markdown]
# **21.** Streamlit 应用每次交互都会重新运行整个脚本。

# %% [markdown]
# **22.** `st.title()` 只能在页面顶部使用。

# %% [markdown]
# **23.** `st.sidebar` 可以创建侧边栏组件。

# %% [markdown]
# **24.** `st.cache_data` 可以缓存函数返回的数据。

# %% [markdown]
# **25.** `st.empty()` 可以创建一个占位符。

# %% [markdown]
# **26.** `st.form()` 可以将多个输入组件组合成一个表单。

# %% [markdown]
# **27.** `st.tabs()` 可以创建多个标签页。

# %% [markdown]
# **28.** `st.file_uploader()` 默认支持多文件上传。

# %% [markdown]
# **29.** `st.color_picker()` 返回十六进制颜色代码。

# %% [markdown]
# **30.** `st.json()` 可以显示 JSON 格式的数据。

# %% [markdown]
# **31.** `st.code()` 可以显示代码并高亮。

# %% [markdown]
# **32.** `st.latex()` 可以显示 LaTeX 数学公式。

# %% [markdown]
# **33.** `st.metric()` 可以显示带标签的数值。

# %% [markdown]
# **34.** `st.download_button()` 可以创建下载按钮。

# %% [markdown]
# **35.** Streamlit 应用只能在本地运行。

# %% [markdown]
# ---
#
# ## 三、填空题 (36-50)

# %% [markdown]
# **36.** `st.set_page_config(page_title="My App")` 设置页面 _______________

# %% [markdown]
# **37.** `st.markdown()` 用于显示 _______________

# %% [markdown]
# **38.** `st.subheader()` 显示 _______________

# %% [markdown]
# **39.** `st.caption()` 显示 _______________

# %% [markdown]
# **40.** `st.help()` 显示函数的 _______________

# %% [markdown]
# **41.** `st.echo()` 可以在应用中显示 _______________

# %% [markdown]
# **42.** `st.spinner()` 在操作时显示 _______________

# %% [markdown]
# **43.** `st balloons()` 显示 _______________

# %% [markdown]
# **44.** `st.snow()` 显示 _______________

# %% [markdown]
# **45.** `st.scatter_chart()` 用于绘制 _______________

# %% [markdown]
# **46.** `st.line_chart()` 用于绘制 _______________

# %% [markdown]
# **47.** `st.bar_chart()` 用于绘制 _______________

# %% [markdown]
# **48.** `st.area_chart()` 用于绘制 _______________

# %% [markdown]
# **49.** `st.altair_chart()` 可以显示 _______________ 图表

# %% [markdown]
# **50.** `st.plotly_chart()` 可以显示 _______________ 图表

# %% [markdown]
# # Streamlit 基础
#
# **总题数**: 20 题
#
# ## 练习说明
# - 请认真阅读每道题目
# - 选择题、判断题、填空题请在下方填写答案
# - 编程题请在代码单元格中编写代码
# - 所有题目仅供练习，不计入成绩
#
# ---

# %% [markdown]
# ## 选择题
# 共 10 题

# %% [markdown]
# ### 第 1 题（easy）
#
# Streamlit 是什么类型的框架？
#
# **选项：**
# A. Web 框架
# B. 桌面应用框架
# C. 数据可视化库
# D. 机器学习框架
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# Streamlit 主要用于什么？
#
# **选项：**
# A. Web 开发
# B. 数据科学和 ML 应用
# C. 游戏开发
# D. 系统编程
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（easy）
#
# 如何运行 Streamlit 应用？
#
# **选项：**
# A. streamlit run app.py
# B. python app.py
# C. streamlit start app.py
# D. python -m streamlit app.py
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 4 题（easy）
#
# Streamlit 文件的扩展名是什么？
#
# **选项：**
# A. .streamlit
# B. .st
# C. .py
# D. .stream
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 5 题（easy）
#
# 如何导入 Streamlit？
#
# **选项：**
# A. import streamlit as st
# B. import Streamlit
# C. from streamlit import *
# D. 都可以
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 6 题（easy）
#
# st.title() 用于显示什么？
#
# **选项：**
# A. 普通文本
# B. 标题
# C. 代码块
# D. 图片
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 7 题（easy）
#
# st.write() 的功能是什么？
#
# **选项：**
# A. 只显示文本
# B. 万能显示函数
# C. 显示表格
# D. 显示图片
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 8 题（medium）
#
# Streamlit 默认运行在哪个端口？
#
# **选项：**
# A. 8000
# B. 8080
# C. 8501
# D. 5000
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 9 题（medium）
#
# 如何添加页面标题？
#
# **选项：**
# A. st.set_page_config()
# B. st.title()
# C. st.header()
# D. st.markdown()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 10 题（easy）
#
# st.markdown() 用于显示什么？
#
# **选项：**
# A. 普通文本
# B. Markdown 格式文本
# C. HTML
# D. 纯文本
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 判断题
# 共 3 题

# %% [markdown]
# ### 第 1 题（easy）
#
# Streamlit 应用需要编写 HTML/CSS。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# Streamlit 支持热重载。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（medium）
#
# Streamlit 应用只能以脚本方式运行。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 编程题
# 共 4 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 编写程序：创建第一个 Streamlit 应用
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 2 题（easy）
#
# 编写程序：使用 Markdown 显示格式化文本
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 3 题（medium）
#
# 编写程序：设置页面标题和图标
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 4 题（easy）
#
# 编写程序：显示数据框
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

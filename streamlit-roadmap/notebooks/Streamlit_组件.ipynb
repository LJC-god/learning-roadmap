# %% [markdown]
# # Streamlit 组件
#
# **总题数**: 20 题
#
# ## 练习说明
# - 请认真阅读每道题目
# - 选择题、判断题、填空题请在下方填写答案
# - 编程题请在代码单元格中编写代码
# - 所有题目仅供练习，不计入成绩
#
# ---

# %% [markdown]
# ## 选择题
# 共 10 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 如何创建文本输入框？
#
# **选项：**
# A. st.text()
# B. st.input()
# C. st.text_input()
# D. st.input_text()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# 如何获取用户输入的数字？
#
# **选项：**
# A. st.number()
# B. st.number_input()
# C. st.int_input()
# D. st.float_input()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（easy）
#
# 如何创建滑块组件？
#
# **选项：**
# A. st.slider()
# B. st.slide()
# C. st.range()
# D. st.drag()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 4 题（easy）
#
# 如何创建复选框？
#
# **选项：**
# A. st.checkbox()
# B. st.check()
# C. st.box()
# D. st.tick()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 5 题（easy）
#
# 如何创建下拉选择框？
#
# **选项：**
# A. st.select()
# B. st.choose()
# C. st.dropdown()
# D. st.pick()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 6 题（easy）
#
# 如何创建单选按钮？
#
# **选项：**
# A. st.radio()
# B. st.select_one()
# C. st.option()
# D. st.choose_one()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 7 题（medium）
#
# 如何创建多选框？
#
# **选项：**
# A. st.multiselect()
# B. st.multiple()
# C. st.checkboxes()
# D. st.select_multiple()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 8 题（medium）
#
# 如何上传文件？
#
# **选项：**
# A. st.file_upload()
# B. st.upload()
# C. st.file()
# D. st.open()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 9 题（easy）
#
# 如何显示进度条？
#
# **选项：**
# A. st.progress()
# B. st.bar()
# C. st.loading()
# D. st.spinner()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 10 题（medium）
#
# 如何创建日期选择器？
#
# **选项：**
# A. st.date_input()
# B. st.date()
# C. st.calendar()
# D. st.pick_date()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 判断题
# 共 2 题

# %% [markdown]
# ### 第 1 题（easy）
#
# Streamlit 组件的返回值会自动显示。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（medium）
#
# st.sidebar 将组件添加到侧边栏。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 编程题
# 共 4 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 编写程序：创建文本输入和显示
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 2 题（easy）
#
# 编写程序：创建滑块并获取值
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 3 题（medium）
#
# 编写程序：创建下拉选择框
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 4 题（medium）
#
# 编写程序：创建文件上传组件
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

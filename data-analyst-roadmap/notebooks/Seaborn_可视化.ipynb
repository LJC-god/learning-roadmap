# %% [markdown]
# # Seaborn 可视化
#
# **总题数**: 12 题
#
# ## 练习说明
# - 请认真阅读每道题目
# - 选择题、判断题、填空题请在下方填写答案
# - 编程题请在代码单元格中编写代码
# - 所有题目仅供练习，不计入成绩
#
# ---

# %% [markdown]
# ## 选择题
# 共 6 题

# %% [markdown]
# ### 第 1 题（easy）
#
# Seaborn 是什么？
#
# **选项：**
# A. 数据分析库
# B. 数据可视化库
# C. Web 框架
# D. 机器学习库
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# 如何导入 Seaborn？
#
# **选项：**
# A. import seaborn
# B. import sns
# C. 两者都可以
# D. import seaborn as sb
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（easy）
#
# 如何绑制关系图？
#
# **选项：**
# A. sns.relplot()
# B. sns.lineplot()
# C. 两者都可以
# D. sns.relation()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 4 题（easy）
#
# 如何绑制分类图？
#
# **选项：**
# A. sns.catplot()
# B. sns.barplot()
# C. 两者都可以
# D. sns.categorical()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 5 题（medium）
#
# 如何设置图表样式？
#
# **选项：**
# A. sns.set_style()
# B. sns.set_theme()
# C. 两者都可以
# D. sns.style()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 6 题（medium）
#
# distplot 现在推荐用什么？
#
# **选项：**
# A. histplot
# B. displot
# C. kdeplot
# D. 两者都可以
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 判断题
# 共 2 题

# %% [markdown]
# ### 第 1 题（easy）
#
# Seaborn 可以与 Matplotlib 结合使用。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（medium）
#
# Seaborn 内置了示例数据集。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 编程题
# 共 2 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 编写程序：绑制散点图
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 2 题（medium）
#
# 编写程序：绑制带回归线的图
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

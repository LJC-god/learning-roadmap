# %% [markdown]
# # NumPy 常用函数
#
# **总题数**: 8 题
#
# ## 练习说明
# - 请认真阅读每道题目
# - 选择题、判断题、填空题请在下方填写答案
# - 编程题请在代码单元格中编写代码
# - 所有题目仅供练习，不计入成绩
#
# ---

# %% [markdown]
# ## 选择题
# 共 4 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 如何计算数组元素的和？
#
# **选项：**
# A. arr.sum()
# B. sum(arr)
# C. 两者都可以
# D. np.total(arr)
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# 如何计算平均值？
#
# **选项：**
# A. arr.mean()
# B. np.mean(arr)
# C. 两者都可以
# D. arr.avg()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（medium）
#
# 如何找到最大值和最小值？
#
# **选项：**
# A. arr.max(), arr.min()
# B. arr.maxmin()
# C. np.max(arr)
# D. 都可以
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 4 题（medium）
#
# 如何计算标准差？
#
# **选项：**
# A. arr.std()
# B. np.std(arr)
# C. 两者都可以
# D. arr.standard_deviation()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 判断题
# 共 1 题

# %% [markdown]
# ### 第 1 题（easy）
#
# np.unique() 可以去除重复元素。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 编程题
# 共 2 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 编写程序：计算统计指标
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 2 题（medium）
#
# 编写程序：使用聚合函数
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

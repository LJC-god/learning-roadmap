# %% [markdown]
# # NumPy 索引与切片
#
# **总题数**: 8 题
#
# ## 练习说明
# - 请认真阅读每道题目
# - 选择题、判断题、填空题请在下方填写答案
# - 编程题请在代码单元格中编写代码
# - 所有题目仅供练习，不计入成绩
#
# ---

# %% [markdown]
# ## 选择题
# 共 4 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 如何选择数组的第一个元素？
#
# **选项：**
# A. arr[1]
# B. arr[0]
# C. arr.first()
# D. arr[1:]
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# 如何选择多行？
#
# **选项：**
# A. arr[0,1]
# B. arr[0:2]
# C. arr(0:2)
# D. arr{0:2}
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（medium）
#
# 什么是布尔索引？
#
# **选项：**
# A. 按值选择
# B. 按条件选择
# C. 按位置选择
# D. 按标签选择
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 4 题（medium）
#
# 如何使用 fancy indexing？
#
# **选项：**
# A. arr[[1,2,3]]
# B. arr[1,2,3]
# C. 两者都可以
# D. arr{1,2,3}
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 判断题
# 共 1 题

# %% [markdown]
# ### 第 1 题（easy）
#
# NumPy 数组切片返回原数组的视图。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 编程题
# 共 2 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 编写程序：选择数组的特定元素
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 2 题（medium）
#
# 编写程序：使用布尔索引筛选数据
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# # 泰坦尼克号项目实战
#
# **总题数**: 12 题
#
# ## 练习说明
# - 请认真阅读每道题目
# - 选择题、判断题、填空题请在下方填写答案
# - 编程题请在代码单元格中编写代码
# - 所有题目仅供练习，不计入成绩
#
# ---

# %% [markdown]
# ## 选择题
# 共 5 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 泰坦尼克号数据集包含什么信息？
#
# **选项：**
# A. 乘客个人信息
# B. 船的信息
# C. 天气信息
# D. 都可以
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# 目标变量是什么？
#
# **选项：**
# A. Age
# B. Fare
# C. Survived
# D. Pclass
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（medium）
#
# 如何加载泰坦尼克号数据？
#
# **选项：**
# A. sns.load_dataset('titanic')
# B. pd.read_csv('titanic.csv')
# C. 两者都可以
# D. pd.read_excel('titanic.xlsx')
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 4 题（medium）
#
# Embarked 列表示什么？
#
# **选项：**
# A. 登船港口
# B. 目的地
# C. 船舱等级
# D. 票价
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 5 题（medium）
#
# Pclass 列表示什么？
#
# **选项：**
# A. 登船港口
# B. 乘客等级
# C. 生存状态
# D. 性别
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 判断题
# 共 2 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 数据集存在缺失值。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（medium）
#
# Age 列需要进行缺失值处理。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 编程题
# 共 3 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 编写程序：加载并探索数据
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 2 题（medium）
#
# 编写程序：分析生存率与性别的关系
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 3 题（medium）
#
# 编写程序：处理缺失值
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

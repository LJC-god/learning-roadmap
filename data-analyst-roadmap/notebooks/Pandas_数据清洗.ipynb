# %% [markdown]
# # Pandas 数据清洗
#
# **总题数**: 8 题
#
# ## 练习说明
# - 请认真阅读每道题目
# - 选择题、判断题、填空题请在下方填写答案
# - 编程题请在代码单元格中编写代码
# - 所有题目仅供练习，不计入成绩
#
# ---

# %% [markdown]
# ## 选择题
# 共 4 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 如何检测缺失值？
#
# **选项：**
# A. isnull()
# B. isna()
# C. 两者都可以
# D. missing()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# 如何删除缺失值？
#
# **选项：**
# A. dropna()
# B. drop_null()
# C. remove_na()
# D. clean_na()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（medium）
#
# 如何填充缺失值？
#
# **选项：**
# A. fillna()
# B. fill_null()
# C. replace_na()
# D. patch_na()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 4 题（medium）
#
# 如何删除重复行？
#
# **选项：**
# A. drop_duplicates()
# B. remove_duplicates()
# C. unique()
# D. dedup()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 判断题
# 共 1 题

# %% [markdown]
# ### 第 1 题（easy）
#
# dropna() 默认删除包含缺失值的行。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 编程题
# 共 2 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 编写程序：检测并处理缺失值
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 2 题（medium）
#
# 编写程序：删除重复数据
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

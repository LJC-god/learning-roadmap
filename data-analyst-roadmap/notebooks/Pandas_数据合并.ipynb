# %% [markdown]
# # Pandas 数据合并
#
# **总题数**: 9 题
#
# ## 练习说明
# - 请认真阅读每道题目
# - 选择题、判断题、填空题请在下方填写答案
# - 编程题请在代码单元格中编写代码
# - 所有题目仅供练习，不计入成绩
#
# ---

# %% [markdown]
# ## 选择题
# 共 4 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 如何合并两个 DataFrame？
#
# **选项：**
# A. pd.merge()
# B. pd.concat()
# C. 两者都可以
# D. pd.join()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# concat 用于什么类型的合并？
#
# **选项：**
# A. 横向合并
# B. 纵向拼接
# C. 都可以
# D. 按索引合并
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（medium）
#
# merge 的 how 参数有哪些选项？
#
# **选项：**
# A. left, right, inner, outer
# B. inner, outer
# C. left, right
# D. 都可以
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 4 题（medium）
#
# join 基于什么进行合并？
#
# **选项：**
# A. 行索引
# B. 列
# C. 都可以
# D. 指定键
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 判断题
# 共 1 题

# %% [markdown]
# ### 第 1 题（easy）
#
# inner join 只保留两边都有的键。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 编程题
# 共 2 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 编写程序：使用 merge 合并数据
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 2 题（medium）
#
# 编写程序：使用 concat 拼接数据
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# # NumPy 数组操作
#
# **总题数**: 10 题
#
# ## 练习说明
# - 请认真阅读每道题目
# - 选择题、判断题、填空题请在下方填写答案
# - 编程题请在代码单元格中编写代码
# - 所有题目仅供练习，不计入成绩
#
# ---

# %% [markdown]
# ## 选择题
# 共 5 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 如何获取数组的形状？
#
# **选项：**
# A. arr.shape
# B. arr.size
# C. arr.dims
# D. arr.length
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# 如何获取数组的元素总数？
#
# **选项：**
# A. arr.shape
# B. arr.size
# C. arr.len
# D. arr.count
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（medium）
#
# 如何重塑数组形状？
#
# **选项：**
# A. arr.reshape()
# B. arr.resize()
# C. arr.shape()
# D. arr.change_shape()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 4 题（medium）
#
# 如何转置数组？
#
# **选项：**
# A. arr.T
# B. arr.transpose()
# C. 两者都可以
# D. arr.swap()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 5 题（medium）
#
# 如何展平数组？
#
# **选项：**
# A. arr.flatten()
# B. arr.flat()
# C. 两者都可以
# D. arr.reshape(-1)
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 判断题
# 共 1 题

# %% [markdown]
# ### 第 1 题（easy）
#
# NumPy 数组支持向量化运算。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 编程题
# 共 2 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 编写程序：进行数组的基本运算
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 2 题（medium）
#
# 编写程序：重塑数组形状
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

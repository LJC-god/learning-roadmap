# %% [markdown]
# # Pandas 数据筛选
#
# **总题数**: 8 题
#
# ## 练习说明
# - 请认真阅读每道题目
# - 选择题、判断题、填空题请在下方填写答案
# - 编程题请在代码单元格中编写代码
# - 所有题目仅供练习，不计入成绩
#
# ---

# %% [markdown]
# ## 选择题
# 共 4 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 如何按条件筛选数据？
#
# **选项：**
# A. df[df['col'] > 5]
# B. df.select()
# C. df.filter()
# D. 都可以
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# 如何使用 loc？
#
# **选项：**
# A. 按标签
# B. 按位置
# C. 按条件
# D. 都可以
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（easy）
#
# 如何使用 iloc？
#
# **选项：**
# A. 按标签
# B. 按位置
# C. 按条件
# D. 都可以
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 4 题（medium）
#
# 如何组合多个条件？
#
# **选项：**
# A. &
# B. |
# C. 两者都可以
# D. and/or
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 判断题
# 共 1 题

# %% [markdown]
# ### 第 1 题（easy）
#
# query() 方法可以用于筛选。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 编程题
# 共 2 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 编写程序：按条件筛选数据
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 2 题（medium）
#
# 编写程序：使用 loc 和 iloc
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

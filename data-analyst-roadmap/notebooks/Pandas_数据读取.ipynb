# %% [markdown]
# # Pandas 数据读取
#
# **总题数**: 8 题
#
# ## 练习说明
# - 请认真阅读每道题目
# - 选择题、判断题、填空题请在下方填写答案
# - 编程题请在代码单元格中编写代码
# - 所有题目仅供练习，不计入成绩
#
# ---

# %% [markdown]
# ## 选择题
# 共 4 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 如何读取 CSV 文件？
#
# **选项：**
# A. pd.read_csv()
# B. pd.csv()
# C. pd.load_csv()
# D. pd.import_csv()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# 如何读取 Excel 文件？
#
# **选项：**
# A. pd.read_excel()
# B. pd.excel()
# C. pd.load_xlsx()
# D. pd.import_excel()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（medium）
#
# read_csv 的哪个参数指定分隔符？
#
# **选项：**
# A. delimiter
# B. sep
# C. 两者都可以
# D. separator
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 4 题（medium）
#
# 如何指定某列为索引？
#
# **选项：**
# A. index_col
# B. set_index
# C. 两者都可以
# D. key_col
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 判断题
# 共 1 题

# %% [markdown]
# ### 第 1 题（easy）
#
# Pandas 可以读取 JSON 文件。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 编程题
# 共 2 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 编写程序：读取 CSV 文件
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 2 题（medium）
#
# 编写程序：读取 Excel 文件
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

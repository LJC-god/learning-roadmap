# %% [markdown]
# # Pandas 分组聚合
#
# **总题数**: 8 题
#
# ## 练习说明
# - 请认真阅读每道题目
# - 选择题、判断题、填空题请在下方填写答案
# - 编程题请在代码单元格中编写代码
# - 所有题目仅供练习，不计入成绩
#
# ---

# %% [markdown]
# ## 选择题
# 共 4 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 分组聚合的步骤是什么？
#
# **选项：**
# A. split-apply-combine
# B. combine-apply-split
# C. apply-combine-split
# D. split-combine-apply
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# groupby 用于什么操作？
#
# **选项：**
# A. 排序
# B. 分组
# C. 筛选
# D. 合并
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（medium）
#
# agg() 函数的作用是什么？
#
# **选项：**
# A. 聚合计算
# B. 分组
# C. 筛选
# D. 排序
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 4 题（medium）
#
# 如何计算分组后的平均值？
#
# **选项：**
# A. groupby().mean()
# B. groupby().avg()
# C. 两者都可以
# D. groupby().calc()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 判断题
# 共 1 题

# %% [markdown]
# ### 第 1 题（easy）
#
# groupby 可以按多个列分组。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 编程题
# 共 2 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 编写程序：按类别分组计算均值
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 2 题（medium）
#
# 编写程序：使用 agg 进行多种聚合
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

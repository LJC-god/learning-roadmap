# %% [markdown]
# # 📚 数据分析 - Pandas DataFrame 基础
#
# 本练习包含 50 道 Pandas DataFrame 相关的练习题。
#
# ---
#
# ## 一、选择题 (1-20)

# %% [markdown]
# **1.** 导入 Pandas 的正确方式是？
#
# A. `import pandas`
#
# B. `import pandas as pd`
#
# C. `from pandas import *`
#
# D. `using pandas`

# %% [markdown]
# **2.** 创建 DataFrame 的常用函数是？
#
# A. `pd.array()`
#
# B. `pd.Series()`
#
# C. `pd.DataFrame()`
#
# D. `pd.read_csv()`

# %% [markdown]
# **3.** `df.shape` 返回的是什么？
#
# A. 行数
#
# B. 列数
#
# C. `(行数, 列数)` 元组
#
# D. 元素总数

# %% [markdown]
# **4.** `df.columns` 返回的是什么？
#
# A. 所有列名
#
# B. 所有行索引
#
# C. 数据类型
#
# D. 统计信息

# %% [markdown]
# **5.** `df.head()` 的作用是？
#
# A. 返回头部数据（默认前 5 行）
#
# B. 返回第一列
#
# C. 返回列名
#
# D. 删除头部

# %% [markdown]
# **6.** `df.info()` 显示什么信息？
#
# A. 统计摘要
#
# B. 数据类型和缺失值
#
# C. 唯一值
#
# D. 相关性

# %% [markdown]
# **7.** `df.describe()` 返回什么？
#
# A. 数据类型
#
# B. 数值列的统计摘要
#
# C. 完整数据
#
# D. 缺失值统计

# %% [markdown]
# **8.** 选择单列的正确方式是？
#
# A. `df['column']`
#
# B. `df.column`
#
# C. A 和 B 都对
#
# D. 只能 `df['column']`

# %% [markdown]
# **9.** `df.loc[]` 和 `df.iloc[]` 的区别是？
#
# A. 没有区别
#
# B. `loc` 用标签，`iloc` 用索引
#
# C. `loc` 用索引，`iloc` 用标签
#
# D. `iloc` 只用于整数索引

# %% [markdown]
# **10.** `df['col'].value_counts()` 的作用是？
#
# A. 统计每列缺失值
#
# B. 统计每列数据类型
#
# C. 统计每个唯一值出现次数
#
# D. 统计每列总和

# %% [markdown]
# **11.** `df.isnull().sum()` 的作用是？
#
# A. 显示是否有空值
#
# B. 返回每列空值数量
#
# C. 删除空值
#
# D. 填充空值

# %% [markdown]
# **12.** `df.dropna()` 的作用是？
#
# A. 检测空值
#
# B. 填充空值
#
# C. 删除含有空值的行
#
# D. 替换空值

# %% [markdown]
# **13.** `df.fillna(0)` 的作用是？
#
# A. 删除空值
#
# B. 检测空值
#
# C. 用 0 填充空值
#
# D. 计算空值数量

# %% [markdown]
# **14.** `df.duplicated()` 的作用是？
#
# A. 删除重复行
#
# B. 检测重复行
#
# C. 保留重复行
#
# D. 统计重复次数

# %% [markdown]
# **15.** `df.drop_duplicates()` 的作用是？
#
# A. 检测重复
#
# B. 标记重复
#
# C. 删除重复行
#
# D. 统计重复

# %% [markdown]
# **16.** `df.sort_values('col')` 的作用是？
#
# A. 按列排序
#
# B. 按索引排序
#
# C. 按值排序
#
# D. 翻转数据

# %% [markdown]
# **17.** `df.rename(columns={'old': 'new'})` 的作用是？
#
# A. 删除列
#
# B. 重命名列
#
# C. 添加列
#
# D. 合并列

# %% [markdown]
# **18.** `df['new_col'] = df['col1'] + df['col2']` 的作用是？
#
# A. 删除列
#
# B. 重命名列
#
# C. 创建新列
#
# D. 合并列

# %% [markdown]
# **19.** `df.apply(func)` 的作用是？
#
# A. 应用函数到每行或每列
#
# B. 删除数据
#
# C. 排序数据
#
# D. 合并数据

# %% [markdown]
# **20.** `df.to_csv('file.csv')` 的作用是？
#
# A. 读取 CSV 文件
#
# B. 导出为 CSV 文件
#
# C. 显示 CSV
#
# D. 压缩 CSV

# %% [markdown]
# ---
#
# ## 二、判断题 (21-35)

# %% [markdown]
# **21.** DataFrame 可以包含不同数据类型的列。

# %% [markdown]
# **22.** `df.head(10)` 会返回前 10 行数据。

# %% [markdown]
# **23.** `df.tail()` 默认返回后 5 行。

# %% [markdown]
# **24.** `df['col']` 返回的是 Series。

# %% [markdown]
# **25.** `df.loc[0:5]` 包含索引 5 的行。

# %% [markdown]
# **26.** `df.iloc[0:5]` 包含索引 5 的行。

# %% [markdown]
# **27.** `df[df['col'] > 10]` 可以进行条件筛选。

# %% [markdown]
# **28.** `df.groupby('col').sum()` 按列分组并求和。

# %% [markdown]
# **29.** `df.pivot_table()` 可以创建透视表。

# %% [markdown]
# **30.** `pd.merge(df1, df2, on='col')` 可以合并两个 DataFrame。

# %% [markdown]
# **31.** `pd.concat([df1, df2])` 可以纵向拼接两个 DataFrame。

# %% [markdown]
# **32.** `df.sample(n=5)` 可以随机抽取 5 行。

# %% [markdown]
# **33.** `df['col'].astype(str)` 可以将列转换为字符串类型。

# %% [markdown]
# **34.** `df.reset_index()` 可以重置索引。

# %% [markdown]
# **35.** `df.set_index('col')` 可以将某列设为索引。

# %% [markdown]
# ---
#
# ## 三、填空题 (36-50)

# %% [markdown]
# **36.** `pd.read_csv('file.csv')` 用于 _______________

# %% [markdown]
# **37.** `df['col'].unique()` 返回 _______________

# %% [markdown]
# **38.** `df['col'].nunique()` 返回 _______________

# %% [markdown]
# **39.** `df['col'].mean()` 计算 _______________

# %% [markdown]
# **40.** `df['col'].median()` 计算 _______________

# %% [markdown]
# **41.** `df.corr()` 计算 _______________

# %% [markdown]
# **42.** `df['col'].str.lower()` 将字符串列转换为 _______________

# %% [markdown]
# **43.** `df['col'].str.contains('abc')` 用于 _______________

# %% [markdown]
# **44.** `pd.to_datetime(df['date_col'])` 用于 _______________

# %% [markdown]
# **45.** `df['date_col'].dt.year` 提取 _______________

# %% [markdown]
# **46.** `df.pivot(index='col1', columns='col2', values='col3')` 创建 _______________

# %% [markdown]
# **47.** `df.melt(id_vars=['col1'])` 用于 _______________

# %% [markdown]
# **48.** `df.assign(new_col=df['col']*2)` 用于 _______________

# %% [markdown]
# **49.** `df.query('col > 10')` 等价于 _______________

# %% [markdown]
# **50.** `df.nsmallest(5, 'col')` 返回 _______________

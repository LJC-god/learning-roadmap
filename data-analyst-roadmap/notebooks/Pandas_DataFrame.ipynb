# %% [markdown]
# # Pandas DataFrame
#
# **总题数**: 25 题
#
# ## 练习说明
# - 请认真阅读每道题目
# - 选择题、判断题、填空题请在下方填写答案
# - 编程题请在代码单元格中编写代码
# - 所有题目仅供练习，不计入成绩
#
# ---

# %% [markdown]
# ## 选择题
# 共 12 题

# %% [markdown]
# ### 第 1 题（easy）
#
# Pandas 是什么的缩写？
#
# **选项：**
# A. Panel Data
# B. Python Data
# C. Panel Dataset
# D. Python Analysis
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# 如何导入 Pandas 库？
#
# **选项：**
# A. import pandas
# B. import pd
# C. from pandas import *
# D. 都可以
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（easy）
#
# DataFrame 是什么？
#
# **选项：**
# A. 一维数组
# B. 二维表格
# C. 三维数组
# D. 树结构
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 4 题（easy）
#
# Series 是什么？
#
# **选项：**
# A. 一维数组
# B. 二维表格
# C. 三维数组
# D. 字典
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 5 题（medium）
#
# 如何从字典创建 DataFrame？
#
# **选项：**
# A. pd.read_dict()
# B. pd.DataFrame()
# C. pd.create_df()
# D. pd.dict_to_df()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 6 题（medium）
#
# 如何查看 DataFrame 的前几行？
#
# **选项：**
# A. df.head()
# B. df.top()
# C. df.first()
# D. df.preview()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 7 题（medium）
#
# 如何查看 DataFrame 的基本信息？
#
# **选项：**
# A. df.info()
# B. df.describe()
# C. df.shape
# D. df.dtypes
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 8 题（medium）
#
# 如何获取 DataFrame 的列名？
#
# **选项：**
# A. df.columns
# B. df.names
# C. df.keys
# D. df.fields
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 9 题（easy）
#
# 如何选择某一列？
#
# **选项：**
# A. df['column']
# B. df.column
# C. 两者都可以
# D. df.get('column')
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 10 题（medium）
#
# 如何添加新列？
#
# **选项：**
# A. df['new_col'] = values
# B. df.new_col = values
# C. 两者都可以
# D. df.append()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 11 题（medium）
#
# 如何删除列？
#
# **选项：**
# A. df.drop('col', axis=1)
# B. df.delete('col')
# C. del df['col']
# D. 都可以
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 12 题（medium）
#
# 如何重命名列？
#
# **选项：**
# A. df.rename()
# B. df.columns = new_names
# C. 两者都可以
# D. df.change_name()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 判断题
# 共 4 题

# %% [markdown]
# ### 第 1 题（easy）
#
# DataFrame 可以包含不同数据类型的列。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# DataFrame 有行索引和列索引。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（medium）
#
# df.loc[] 用于按标签选择数据。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 4 题（medium）
#
# df.iloc[] 用于按位置选择数据。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 编程题
# 共 5 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 编写程序：创建简单的 DataFrame
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 2 题（easy）
#
# 编写程序：查看 DataFrame 的前3行
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 3 题（medium）
#
# 编写程序：选择特定的列
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 4 题（medium）
#
# 编写程序：添加新列
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 5 题（medium）
#
# 编写程序：使用 loc 选择数据
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

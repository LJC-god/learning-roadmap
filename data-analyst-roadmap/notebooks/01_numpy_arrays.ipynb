# %% [markdown]
# # 📚 数据分析 - NumPy 数组基础
#
# 本练习包含 50 道 NumPy 数组相关的练习题。
#
# ---
#
# ## 一、选择题 (1-20)

# %% [markdown]
# **1.** 导入 NumPy 的正确方式是？
#
# A. `import numpy`
#
# B. `import numpy as np`
#
# C. `from numpy import *`
#
# D. `using numpy`

# %% [markdown]
# **2.** `np.array([1, 2, 3])` 创建的数组类型是？
#
# A. `list`
#
# B. `tuple`
#
# C. `ndarray`
#
# D. `array`

# %% [markdown]
# **3.** `np.zeros(5)` 创建的数组内容是？
#
# A. `[0, 0, 0, 0, 0]`
#
# B. `[1, 1, 1, 1, 1]`
#
# C. `[0.0, 0.0, 0.0]`
#
# D. 空数组

# %% [markdown]
# **4.** `np.arange(10)` 生成的范围是？
#
# A. `[0, 1, 2, ..., 9]`
#
# B. `[1, 2, 3, ..., 10]`
#
# C. `[0, 1, 2, ..., 10]`
#
# D. `[0.0, 1.0, ..., 9.0]`

# %% [markdown]
# **5.** `arr.shape` 返回的是什么？
#
# A. 数组元素个数
#
# B. 数组维度
#
# C. 数组的形状元组
#
# D. 数组数据类型

# %% [markdown]
# **6.** `arr.ndim` 表示什么？
#
# A. 元素个数
#
# B. 数组维度
#
# C. 数据类型
#
# D. 数组大小

# %% [markdown]
# **7.** `np.linspace(0, 10, 5)` 生成几个数？
#
# A. 3 个
#
# B. 5 个
#
# C. 10 个
#
# D. 11 个

# %% [markdown]
# **8.** `arr.dtype` 返回的是什么？
#
# A. 数组形状
#
# B. 数组维度
#
# C. 数据类型
#
# D. 元素个数

# %% [markdown]
# **9.** `np.ones((2, 3))` 创建的数组形状是？
#
# A. `(2,)`
#
# B. `(3,)`
#
# C. `(2, 3)`
#
# D. `(3, 2)`

# %% [markdown]
# **10.** `arr.size` 返回什么？
#
# A. 维度数
#
# B. 元素总个数
#
# C. 字节数
#
# D. 形状元组

# %% [markdown]
# **11.** 将列表 `[1, 2, 3]` 转换为 NumPy 数组的正确方式是？
#
# A. `array([1, 2, 3])`
#
# B. `np.array([1, 2, 3])`
#
# C. `numpy([1, 2, 3])`
#
# D. `np.create([1, 2, 3])`

# %% [markdown]
# **12.** `np.eye(3)` 创建的是什么矩阵？
#
# A. 全零矩阵
#
# B. 全一矩阵
#
# C. 单位矩阵
#
# D. 对角矩阵

# %% [markdown]
# **13.** `arr.astype(float)` 的作用是？
#
# A. 修改原数组
#
# B. 返回新数组
#
# C. 删除元素
#
# D. 排序数组

# %% [markdown]
# **14.** 2D 数组的访问方式是？
#
# A. `arr[i][j]`
#
# B. `arr[i, j]`
#
# C. A 和 B 都对
#
# D. 只能 `arr[i][j]`

# %% [markdown]
# **15.** `arr.reshape(3, 4)` 要求原数组有多少个元素？
#
# A. 3 个
#
# B. 4 个
#
# C. 7 个
#
# D. 12 个

# %% [markdown]
# **16.** `np.random.rand(3)` 生成什么范围的值？
#
# A. `[0, 1)` 区间
#
# B. `[0, 1]` 区间
#
# C. 正态分布
#
# D. 整数

# %% [markdown]
# **17.** `np.random.randint(0, 10, 5)` 生成几个随机整数？
#
# A. 1-5 个
#
# B. 5 个
#
# C. 10 个
#
# D. 不确定

# %% [markdown]
# **18.** 复制数组的正确方式是？
#
# A. `arr2 = arr`
#
# B. `arr2 = arr.copy()`
#
# C. `arr2 = list(arr)`
#
# D. `np.copy(arr)`

# %% [markdown]
# **19.** `arr.flatten()` 的作用是？
#
# A. 改变数组形状
#
# B. 返回一维数组
#
# C. 删除维度
#
# D. 转置数组

# %% [markdown]
# **20.** `np.full((2, 2), 7)` 创建的数组内容是？
#
# A. `[[7, 7], [7, 7]]`
#
# B. `[[7]]`
#
# C. `[7, 7]`
#
# D. `[[7, 7, 7, 7]]`

# %% [markdown]
# ---
#
# ## 二、判断题 (21-35)

# %% [markdown]
# **21.** NumPy 数组支持广播机制。

# %% [markdown]
# **22.** `np.zeros(5)` 和 `np.zeros((5,))` 创建的数组形状相同。

# %% [markdown]
# **23.** 数组可以直接使用列表的所有操作。

# %% [markdown]
# **24.** `arr.reshape(-1)` 可以将数组转换为一维。

# %% [markdown]
# **25.** `np.arange(5)` 和 `np.array(range(5))` 结果相同。

# %% [markdown]
# **26.** NumPy 数组的元素类型必须一致。

# %% [markdown]
# **27.** `arr.T` 会返回原数组的转置视图。

# %% [markdown]
# **28.** `np.concatenate()` 可以合并多个数组。

# %% [markdown]
# **29.** NumPy 数组切片返回的是原数组的视图。

# %% [markdown]
# **30.** `arr[::2]` 表示每隔一个元素取一次。

# %% [markdown]
# **31.** `np.random.seed(0)` 设置随机种子后，结果可复现。

# %% [markdown]
# **32.** 2D 数组切片 `arr[1:3, 0:2]` 返回 2×2 的子数组。

# %% [markdown]
# **33.** `arr.sum()` 默认对所有元素求和。

# %% [markdown]
# **34.** `np.unique(arr)` 可以返回数组中的唯一值。

# %% [markdown]
# **35.** `arr.sort()` 会对原数组进行原地排序。

# %% [markdown]
# ---
#
# ## 三、填空题 (36-50)

# %% [markdown]
# **36.** `np.array([1, 2, 3]).shape` 返回 _______________

# %% [markdown]
# **37.** `np.zeros((3, 3)).shape` 返回 _______________

# %% [markdown]
# **38.** `np.arange(0, 10, 2)` 返回 _______________

# %% [markdown]
# **39.** `np.linspace(0, 1, 5)` 返回 _______________ 个数

# %% [markdown]
# **40.** `arr[[True, False, True]]` 会筛选出第 _______________ 个元素

# %% [markdown]
# **41.** `np.random.random((2, 2))` 生成 _______________ 形状的数组

# %% [markdown]
# **42.** `arr.min()` 和 _______________ 函数都能找到最小值

# %% [markdown]
# **43.** `arr.max()` 的别名是 _______________

# %% [markdown]
# **44.** `np.mean(arr)` 计算的是 _______________

# %% [markdown]
# **45.** `np.std(arr)` 计算的是 _______________

# %% [markdown]
# **46.** `np.var(arr)` 计算的是 _______________

# %% [markdown]
# **47.** `np.dot(a, b)` 计算的是 _______________

# %% [markdown]
# **48.** `arr.sum(axis=1)` 按 _______________ 方向求和

# %% [markdown]
# **49.** `np.save('arr.npy', arr)` 保存的文件格式是 _______________

# %% [markdown]
# **50.** `np.load('arr.npy')` 加载的文件格式是 _______________

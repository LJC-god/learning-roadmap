# %% [markdown]
# # Matplotlib 可视化
#
# **总题数**: 23 题
#
# ## 练习说明
# - 请认真阅读每道题目
# - 选择题、判断题、填空题请在下方填写答案
# - 编程题请在代码单元格中编写代码
# - 所有题目仅供练习，不计入成绩
#
# ---

# %% [markdown]
# ## 选择题
# 共 10 题

# %% [markdown]
# ### 第 1 题（easy）
#
# Matplotlib 的哪个子模块用于绑图？
#
# **选项：**
# A. matplotlib.pylab
# B. matplotlib.pyplot
# C. matplotlib.graph
# D. matplotlib.chart
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# 如何导入 pyplot？
#
# **选项：**
# A. import matplotlib.pyplot as plt
# B. import pyplot
# C. from matplotlib import pyplot
# D. 都可以
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（easy）
#
# 如何创建一个新图表？
#
# **选项：**
# A. plt.plot()
# B. plt.figure()
# C. plt.new()
# D. plt.create()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 4 题（easy）
#
# 如何绑制折线图？
#
# **选项：**
# A. plt.scatter()
# B. plt.line()
# C. plt.plot()
# D. plt.draw()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 5 题（medium）
#
# 如何添加图表标题？
#
# **选项：**
# A. plt.title()
# B. plt.heading()
# C. plt.caption()
# D. plt.label()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 6 题（medium）
#
# 如何添加轴标签？
#
# **选项：**
# A. plt.xlabel() / plt.ylabel()
# B. plt.xlabel / plt.ylabel()
# C. plt.label_x() / plt.label_y()
# D. plt.axis_label()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 7 题（medium）
#
# 如何显示图例？
#
# **选项：**
# A. plt.legend()
# B. plt.key()
# C. plt.show()
# D. plt.display()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 8 题（medium）
#
# 如何将图表保存为图片？
#
# **选项：**
# A. plt.save()
# B. plt.savefig()
# C. plt.export()
# D. plt.image()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 9 题（medium）
#
# 如何绑制散点图？
#
# **选项：**
# A. plt.scatter(x, y)
# B. plt.point(x, y)
# C. plt.dot(x, y)
# D. plt.scatterplot(x, y)
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 10 题（medium）
#
# 如何绑制柱状图？
#
# **选项：**
# A. plt.bar()
# B. plt.histogram()
# C. plt.column()
# D. plt.barplot()
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 判断题
# 共 4 题

# %% [markdown]
# ### 第 1 题（easy）
#
# plt.show() 必须在最后调用以显示图表。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 2 题（easy）
#
# plt.plot() 只能绑制折线图。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 3 题（medium）
#
# 可以使用 plt.grid(True) 添加网格线。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ### 第 4 题（medium）
#
# plt.xlim() 和 plt.ylim() 设置坐标轴范围。
#
# **判断：** True / False
#
# **你的答案：**
#
# ---

# %% [markdown]
# ## 编程题
# 共 5 题

# %% [markdown]
# ### 第 1 题（easy）
#
# 编写程序：绑制简单的折线图
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 2 题（medium）
#
# 编写程序：绑制带标题和标签的散点图
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 3 题（medium）
#
# 编写程序：绑制柱状图比较数据
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 4 题（medium）
#
# 编写程序：在同一图表中绑制多条线
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：

# %% [markdown]
# ### 第 5 题（medium）
#
# 编写程序：自定义图表样式
#
# ```python
# # 在下方代码单元格中编写代码
# ```
#
# ---

# %%
# 你的代码：
